# %% [markdown]
# <a href="https://colab.research.google.com/github/Triveni18/Python/blob/main/Pandas/PandasHead01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the pandas library, which is used for data manipulation and analysis
import pandas as pd

# Read data from an Excel file named 'EMP.xlsx' located in the '/content/' directory
# Specify 'Sheet1' as the sheet to load into a DataFrame called df1
df1 = pd.read_excel('/content/EMP.xlsx', sheet_name='Sheet1')

# Print the first five rows of the DataFrame to get a quick overview of the data
print(df1.head())
# Out:
#   EMPID       EMPNAME  SALARY        DOJ
# 0  E001  Ananya Singh   55000 2019-04-15
# 1  E002   Rohan Mehta   62000 2020-07-01
# 2  E003  Priya Sharma   48000 2018-11-20
# 3  E004   Arjun Verma   70000 2021-02-10
# 4  E005   Neha Kapoor   53000 2017-09-05
