# %% [markdown]
# <a href="https://colab.research.google.com/github/Triveni18/Python/blob/main/Pandas/PandasShape01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the Excel file into a DataFrame
# 'df1' stores the data from 'Sheet1' of the EMP.xlsx file
df1 = pd.read_excel('/content/EMP.xlsx', sheet_name='Sheet1')

# Retrieve the dimensions of the DataFrame
# df1.shape returns a tuple representing (number of rows, number of columns)
print("The shape (rows, columns) of the DataFrame is:", df1.shape)
# Out:
# (30, 4)
