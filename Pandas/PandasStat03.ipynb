# %% [markdown]
# <a href="https://colab.research.google.com/github/Triveni18/Python/blob/main/Pandas/PandasStat03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the pandas library, which is used for data manipulation and analysis.
# Pandas provides data structures like DataFrames for handling tabular data efficiently.
import pandas as pd

# Load the Excel file from the specified path and select the specific sheet.
# Ensure the file path is correct for your Google Colab or local environment, and that 'EMP.xlsx' is uploaded if necessary.
# This reads the Excel file into a DataFrame object named 'df', which represents the data in a tabular format.
# The 'sheet_name' parameter specifies which sheet in the Excel workbook to load (in this case, "Sheet1").
df = pd.read_excel('/content/EMP.xlsx', sheet_name="Sheet1")

# Filter the DataFrame to include only rows where the 'SALARY' column is greater than 65000.
# This uses boolean indexing: df['SALARY'] > 65000 creates a boolean mask, and df[...] applies it to select matching rows.
dec = df[df['SALARY'] > 65000]

# Display the filtered results by printing the DataFrame subset.
print(dec)

# Filter the DataFrame to include only rows where the 'SALARY' column is less than or equal to 50000.
dec = df[df['SALARY'] <= 50000]

# Print a descriptive message followed by the filtered DataFrame.
# The '\n' adds a newline for better readability in the output.
print('Details of People whose salary is less than 50000 \n ', dec)

# Filter the DataFrame to include only rows where the 'SALARY' is equal to the maximum salary in the dataset.
# df['SALARY'].max() computes the highest value in the 'SALARY' column.
dec = df[df['SALARY'] == df['SALARY'].max()]

# Print a descriptive message followed by the filtered DataFrame for the maximum salary.
print('Details of People whose salary is is equal to max  \n ', dec)

# Filter the DataFrame to include only rows where the 'SALARY' is equal to the minimum salary in the dataset.
# df['SALARY'].min() computes the lowest value in the 'SALARY' column.
dec = df[df['SALARY'] == df['SALARY'].min()]

# Print a descriptive message followed by the filtered DataFrame for the minimum salary.
print('Details of People whose salary is is equal to min  \n ', dec)

# Filter the DataFrame to include only rows where the 'SALARY' is less than or equal to the average salary.
# df['SALARY'].mean() calculates the mean (average) value of the 'SALARY' column.
dec = df[df['SALARY'] <= df['SALARY'].mean()]

# Print a descriptive message followed by the filtered DataFrame for salaries below or equal to the average.
print('Details of People whose salary is less than  Avg  \n ', dec)

# Filter the DataFrame to include only rows where the 'SALARY' is greater than or equal to the average salary.
dec = df[df['SALARY'] >= df['SALARY'].mean()]

# Print a descriptive message followed by the filtered DataFrame for salaries above or equal to the average.
print('Details of People whose salary is greater than  Avg  \n ', dec)
# Out:
#    EMPID          EMPNAME  SALARY        DOJ
# 3   E004      Arjun Verma   70000 2021-02-10
# 5   E006       Vikram Rao   75000 2022-06-18
# 7   E008      Suresh Nair   68000 2019-08-25
# 9   E010     Dev Malhotra   80000 2023-03-22
# 12  E013  Amit Chatterjee   72000 2021-11-02
# 16  E017    Manish Tiwari   69000 2018-12-05
# 19  E020     Harish Patel   71000 2021-01-12
# 21  E022      Karan Bhatt   75000 2022-08-19
# 23  E024      Mohit Sinha   68000 2018-09-23
# 25  E026     Ajay Prakash   80000 2023-04-16
# 27  E028     Rohit Khanna   72000 2020-12-03
# 29  E030     Deepak Yadav   77000 2022-03-20
# Details of People whose salary is less than 50000
#      EMPID         EMPNAME  SALARY        DOJ
# 2   E003    Priya Sharma   48000 2018-11-20
# 6   E007     Kavita Iyer   46000 2016-12-12
# 11  E012  Pooja Deshmukh   49000 2017-03-09
# 15  E016     Sneha Reddy   46000 2016-10-21
# 18  E019  Shalini Saxena   48000 2016-04-30
# 22  E023    Ritu Agarwal   47000 2016-11-11
# 26  E027   Nidhi Chauhan   49000 2016-02-25
# Details of People whose salary is is equal to max
#      EMPID       EMPNAME  SALARY        DOJ
# 9   E010  Dev Malhotra   80000 2023-03-22
# 25  E026  Ajay Prakash   80000 2023-04-16
# Details of People whose salary is is equal to min
#      EMPID      EMPNAME  SALARY        DOJ
# 6   E007  Kavita Iyer   46000 2016-12-12
# 15  E016  Sneha Reddy   46000 2016-10-21
# Details of People whose salary is less than  Avg
#      EMPID          EMPNAME  SALARY        DOJ
# 0   E001     Ananya Singh   55000 2019-04-15
# 2   E003     Priya Sharma   48000 2018-11-20
# 4   E005      Neha Kapoor   53000 2017-09-05
# 6   E007      Kavita Iyer   46000 2016-12-12
# 8   E009      Meera Joshi   51000 2020-01-30
# 10  E011  Sanjay Kulkarni   57000 2018-05-14
# 11  E012   Pooja Deshmukh   49000 2017-03-09
# 13  E014    Shruti Bansal   53000 2019-06-27
# 15  E016      Sneha Reddy   46000 2016-10-21
# 17  E018      Alok Mishra   56000 2017-07-18
# 18  E019   Shalini Saxena   48000 2016-04-30
# 20  E021      Divya Nanda   52000 2019-02-08
# 22  E023     Ritu Agarwal   47000 2016-11-11
# 24  E025    Tanya D’Souza   54000 2017-05-07
# 26  E027    Nidhi Chauhan   49000 2016-02-25
# 28  E029    Pallavi Menon   51000 2019-10-29
# Details of People whose salary is greater than  Avg
#      EMPID          EMPNAME  SALARY        DOJ
# 1   E002      Rohan Mehta   62000 2020-07-01
# 3   E004      Arjun Verma   70000 2021-02-10
# 5   E006       Vikram Rao   75000 2022-06-18
# 7   E008      Suresh Nair   68000 2019-08-25
# 9   E010     Dev Malhotra   80000 2023-03-22
# 12  E013  Amit Chatterjee   72000 2021-11-02
# 14  E015     Rajeev Gupta   64000 2020-09-15
# 16  E017    Manish Tiwari   69000 2018-12-05
# 19  E020     Harish Patel   71000 2021-01-12
# 21  E022      Karan Bhatt   75000 2022-08-19
# 23  E024      Mohit Sinha   68000 2018-09-23
# 25  E026     Ajay Prakash   80000 2023-04-16
# 27  E028     Rohit Khanna   72000 2020-12-03
# 29  E030     Deepak Yadav   77000 2022-03-20
