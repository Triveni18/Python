# %% [markdown]
# <a href="https://colab.research.google.com/github/Triveni18/Python/blob/main/NumPy/NumpyArray02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import all functions and classes from the numpy library directly into the current namespace
from numpy import *

# Create a numpy array 'arr' containing the integers 110, 120, 230, 140, and 150
arr = array([110, 120, 230, 140, 150])

# Print a newline, followed by the string "Content of Array", another newline, and then the contents of the array
print('\n Content of Array \n' , arr)
# Out:
#  Content of Array
#  [110 120 230 140 150]
