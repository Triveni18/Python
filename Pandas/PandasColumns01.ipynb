# %% [markdown]
# <a href="https://colab.research.google.com/github/Triveni18/Python/blob/main/Pandas/PandasColumns01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the Excel file from the specified path and select the specific sheet
# Ensure the file path is correct for your Google Colab or local environment
df = pd.read_excel('/content/EMP.xlsx', sheet_name="Sheet1")

# Display all column headers present in the DataFrame to verify the data structure
print(df.columns)

# Select and print only the EMPID, EMPNAME, and DOJ columns in a tabular format
# Using double brackets returns these columns side-by-side
print(df[['EMPID', 'EMPNAME', 'DOJ']])
# Out:
# Index(['EMPID', 'EMPNAME', 'SALARY', 'DOJ'], dtype='object')
#    EMPID          EMPNAME        DOJ
# 0   E001     Ananya Singh 2019-04-15
# 1   E002      Rohan Mehta 2020-07-01
# 2   E003     Priya Sharma 2018-11-20
# 3   E004      Arjun Verma 2021-02-10
# 4   E005      Neha Kapoor 2017-09-05
# 5   E006       Vikram Rao 2022-06-18
# 6   E007      Kavita Iyer 2016-12-12
# 7   E008      Suresh Nair 2019-08-25
# 8   E009      Meera Joshi 2020-01-30
# 9   E010     Dev Malhotra 2023-03-22
# 10  E011  Sanjay Kulkarni 2018-05-14
# 11  E012   Pooja Deshmukh 2017-03-09
# 12  E013  Amit Chatterjee 2021-11-02
# 13  E014    Shruti Bansal 2019-06-27
# 14  E015     Rajeev Gupta 2020-09-15
# 15  E016      Sneha Reddy 2016-10-21
# 16  E017    Manish Tiwari 2018-12-05
# 17  E018      Alok Mishra 2017-07-18
# 18  E019   Shalini Saxena 2016-04-30
# 19  E020     Harish Patel 2021-01-12
# 20  E021      Divya Nanda 2019-02-08
# 21  E022      Karan Bhatt 2022-08-19
# 22  E023     Ritu Agarwal 2016-11-11
# ...
